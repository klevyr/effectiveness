# %%
import pandas as pd
import polars as pl
import yaml
from pathlib import Path
from dataclasses import dataclass, field
#pd.options.display.max_columns = None
with open("cfg/dev.yml", encoding="utf-8") as fh:
    cfg: dict[str, Any] = yaml.safe_load(fh)
